# %%
import pandas as pd

# Load the dataset using a relative path - assuming the file is in the same directory as the notebook
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Display the first few rows of the dataset with styling
df.head().style.set_table_styles([
    {'selector': 'table', 'props': [('border', '1px solid black')]},
    {'selector': 'th', 'props': [('background-color', 'green'), ('color', 'black'), ('border', '1px solid black')]},
    {'selector': 'td', 'props': [('background-color', 'black'), ('color', 'white'), ('border', '1px solid black')]},
])
# Out:
# <style type="text/css">
# #T_6219e table {
#   border: 1px solid black;
# }
# #T_6219e th {
#   background-color: green;
#   color: black;
#   border: 1px solid black;
# }
# #T_6219e td {
#   background-color: black;
#   color: white;
#   border: 1px solid black;
# }
# </style>
# <table id="T_6219e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6219e_level0_col0" class="col_heading level0 col0" >track_name</th>
#       <th id="T_6219e_level0_col1" class="col_heading level0 col1" >artist(s)_name</th>
#       <th id="T_6219e_level0_col2" class="col_heading level0 col2" >artist_count</th>
#       <th id="T_6219e_level0_col3" class="col_heading level0 col3" >released_year</th>
#       <th id="T_6219e_level0_col4" class="col_heading level0 col4" >released_month</th>
#       <th id="T_6219e_level0_col5" class="col_heading level0 col5" >released_day</th>
#       <th id="T_6219e_level0_col6" class="col_heading level0 col6" >in_spotify_playlists</th>
#       <th id="T_6219e_level0_col7" class="col_heading level0 col7" >in_spotify_charts</th>
#       <th id="T_6219e_level0_col8" class="col_heading level0 col8" >streams</th>
#       <th id="T_6219e_level0_col9" class="col_heading level0 col9" >in_apple_playlists</th>
#       <th id="T_6219e_level0_col10" class="col_heading level0 col10" >in_apple_charts</th>
#       <th id="T_6219e_level0_col11" class="col_heading level0 col11" >in_deezer_playlists</th>
#       <th id="T_6219e_level0_col12" class="col_heading level0 col12" >in_deezer_charts</th>
#       <th id="T_6219e_level0_col13" class="col_heading level0 col13" >in_shazam_charts</th>
#       <th id="T_6219e_level0_col14" class="col_heading level0 col14" >bpm</th>
#       <th id="T_6219e_level0_col15" class="col_heading level0 col15" >key</th>
#       <th id="T_6219e_level0_col16" class="col_heading level0 col16" >mode</th>
#       <th id="T_6219e_level0_col17" class="col_heading level0 col17" >danceability_%</th>
#       <th id="T_6219e_level0_col18" class="col_heading level0 col18" >valence_%</th>
#       <th id="T_6219e_level0_col19" class="col_heading level0 col19" >energy_%</th>
#       <th id="T_6219e_level0_col20" class="col_heading level0 col20" >acousticness_%</th>
#       <th id="T_6219e_level0_col21" class="col_heading level0 col21" >instrumentalness_%</th>
#       <th id="T_6219e_level0_col22" class="col_heading level0 col22" >liveness_%</th>
#       <th id="T_6219e_level0_col23" class="col_heading level0 col23" >speechiness_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6219e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6219e_row0_col0" class="data row0 col0" >Seven (feat. Latto) (Explicit Ver.)</td>
#       <td id="T_6219e_row0_col1" class="data row0 col1" >Latto, Jung Kook</td>
#       <td id="T_6219e_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_6219e_row0_col3" class="data row0 col3" >2023</td>
#       <td id="T_6219e_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_6219e_row0_col5" class="data row0 col5" >14</td>
#       <td id="T_6219e_row0_col6" class="data row0 col6" >553</td>
#       <td id="T_6219e_row0_col7" class="data row0 col7" >147</td>
#       <td id="T_6219e_row0_col8" class="data row0 col8" >141381703</td>
#       <td id="T_6219e_row0_col9" class="data row0 col9" >43</td>
#       <td id="T_6219e_row0_col10" class="data row0 col10" >263</td>
#       <td id="T_6219e_row0_col11" class="data row0 col11" >45</td>
#       <td id="T_6219e_row0_col12" class="data row0 col12" >10</td>
#       <td id="T_6219e_row0_col13" class="data row0 col13" >826</td>
#       <td id="T_6219e_row0_col14" class="data row0 col14" >125</td>
#       <td id="T_6219e_row0_col15" class="data row0 col15" >B</td>
#       <td id="T_6219e_row0_col16" class="data row0 col16" >Major</td>
#       <td id="T_6219e_row0_col17" class="data row0 col17" >80</td>
#       <td id="T_6219e_row0_col18" class="data row0 col18" >89</td>
#       <td id="T_6219e_row0_col19" class="data row0 col19" >83</td>
#       <td id="T_6219e_row0_col20" class="data row0 col20" >31</td>
#       <td id="T_6219e_row0_col21" class="data row0 col21" >0</td>
#       <td id="T_6219e_row0_col22" class="data row0 col22" >8</td>
#       <td id="T_6219e_row0_col23" class="data row0 col23" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6219e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6219e_row1_col0" class="data row1 col0" >LALA</td>
#       <td id="T_6219e_row1_col1" class="data row1 col1" >Myke Towers</td>
#       <td id="T_6219e_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_6219e_row1_col3" class="data row1 col3" >2023</td>
#       <td id="T_6219e_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_6219e_row1_col5" class="data row1 col5" >23</td>
#       <td id="T_6219e_row1_col6" class="data row1 col6" >1474</td>
#       <td id="T_6219e_row1_col7" class="data row1 col7" >48</td>
#       <td id="T_6219e_row1_col8" class="data row1 col8" >133716286</td>
#       <td id="T_6219e_row1_col9" class="data row1 col9" >48</td>
#       <td id="T_6219e_row1_col10" class="data row1 col10" >126</td>
#       <td id="T_6219e_row1_col11" class="data row1 col11" >58</td>
#       <td id="T_6219e_row1_col12" class="data row1 col12" >14</td>
#       <td id="T_6219e_row1_col13" class="data row1 col13" >382</td>
#       <td id="T_6219e_row1_col14" class="data row1 col14" >92</td>
#       <td id="T_6219e_row1_col15" class="data row1 col15" >C#</td>
#       <td id="T_6219e_row1_col16" class="data row1 col16" >Major</td>
#       <td id="T_6219e_row1_col17" class="data row1 col17" >71</td>
#       <td id="T_6219e_row1_col18" class="data row1 col18" >61</td>
#       <td id="T_6219e_row1_col19" class="data row1 col19" >74</td>
#       <td id="T_6219e_row1_col20" class="data row1 col20" >7</td>
#       <td id="T_6219e_row1_col21" class="data row1 col21" >0</td>
#       <td id="T_6219e_row1_col22" class="data row1 col22" >10</td>
#       <td id="T_6219e_row1_col23" class="data row1 col23" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6219e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6219e_row2_col0" class="data row2 col0" >vampire</td>
#       <td id="T_6219e_row2_col1" class="data row2 col1" >Olivia Rodrigo</td>
#       <td id="T_6219e_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_6219e_row2_col3" class="data row2 col3" >2023</td>
#       <td id="T_6219e_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_6219e_row2_col5" class="data row2 col5" >30</td>
#       <td id="T_6219e_row2_col6" class="data row2 col6" >1397</td>
#       <td id="T_6219e_row2_col7" class="data row2 col7" >113</td>
#       <td id="T_6219e_row2_col8" class="data row2 col8" >140003974</td>
#       <td id="T_6219e_row2_col9" class="data row2 col9" >94</td>
#       <td id="T_6219e_row2_col10" class="data row2 col10" >207</td>
#       <td id="T_6219e_row2_col11" class="data row2 col11" >91</td>
#       <td id="T_6219e_row2_col12" class="data row2 col12" >14</td>
#       <td id="T_6219e_row2_col13" class="data row2 col13" >949</td>
#       <td id="T_6219e_row2_col14" class="data row2 col14" >138</td>
#       <td id="T_6219e_row2_col15" class="data row2 col15" >F</td>
#       <td id="T_6219e_row2_col16" class="data row2 col16" >Major</td>
#       <td id="T_6219e_row2_col17" class="data row2 col17" >51</td>
#       <td id="T_6219e_row2_col18" class="data row2 col18" >32</td>
#       <td id="T_6219e_row2_col19" class="data row2 col19" >53</td>
#       <td id="T_6219e_row2_col20" class="data row2 col20" >17</td>
#       <td id="T_6219e_row2_col21" class="data row2 col21" >0</td>
#       <td id="T_6219e_row2_col22" class="data row2 col22" >31</td>
#       <td id="T_6219e_row2_col23" class="data row2 col23" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6219e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6219e_row3_col0" class="data row3 col0" >Cruel Summer</td>
#       <td id="T_6219e_row3_col1" class="data row3 col1" >Taylor Swift</td>
#       <td id="T_6219e_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_6219e_row3_col3" class="data row3 col3" >2019</td>
#       <td

# %% [markdown]
# 1. Overview of the Dataset
# How many rows and columns does the dataset contain??

# %%
# Install pip colorama using !pip install colorama
import pandas as pd
from colorama import Fore, Back, Style

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')
# prompt: create a program that counts the number of rows and columns in the spotify-2023.csv

# Get the number of rows and columns
num_rows = df.shape[0]
num_cols = df.shape[1]

# Print the results
print(Fore.BLACK + Back.WHITE + Style.BRIGHT + '*************************')
print(Fore.BLACK + Back.GREEN + Style.BRIGHT + '* Number of rows: ' + str(num_rows) + '   *')
print(Fore.BLACK + Back.GREEN + Style.BRIGHT + '* Number of cols: ' + str(num_cols) + '    *')
print(Fore.BLACK + Back.WHITE + Style.BRIGHT + '*************************' + Style.RESET_ALL)
# Out:
# *************************
# * Number of rows: 953   *
# * Number of cols: 24    *
# *************************

# %% [markdown]
# What are the data types of each column? Are there any missing values?

# %%
# prompt: create a program that list the data types of each column and provide values for missing quantity, style the output in a table using numpy

import pandas as pd
import numpy as np

# Get data types of each column
data_types = df.dtypes

# Get the number of missing values in each column
missing_values = df.isnull().sum()

# Create a new DataFrame with the results
results_df = pd.DataFrame({'Data Type': data_types, 'Missing Values': missing_values})

# Style the DataFrame
styled_results = results_df.style.set_table_styles([
    {'selector': 'table', 'props': [('border', '1px solid black')]},
    {'selector': 'th', 'props': [('background-color', 'GREEN'), ('color', 'black'), ('border', '1px solid black')]},
    {'selector': 'td', 'props': [('background-color', 'black'), ('color', 'white'), ('border', '1px solid black')]},
])


# Display the styled DataFrame
display(styled_results)
# Out:
# <style type="text/css">
# #T_5c2a4 table {
#   border: 1px solid black;
# }
# #T_5c2a4 th {
#   background-color: GREEN;
#   color: black;
#   border: 1px solid black;
# }
# #T_5c2a4 td {
#   background-color: black;
#   color: white;
#   border: 1px solid black;
# }
# </style>
# <table id="T_5c2a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c2a4_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_5c2a4_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c2a4_level0_row0" class="row_heading level0 row0" >track_name</th>
#       <td id="T_5c2a4_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_5c2a4_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row1" class="row_heading level0 row1" >artist(s)_name</th>
#       <td id="T_5c2a4_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_5c2a4_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row2" class="row_heading level0 row2" >artist_count</th>
#       <td id="T_5c2a4_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_5c2a4_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row3" class="row_heading level0 row3" >released_year</th>
#       <td id="T_5c2a4_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_5c2a4_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row4" class="row_heading level0 row4" >released_month</th>
#       <td id="T_5c2a4_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_5c2a4_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row5" class="row_heading level0 row5" >released_day</th>
#       <td id="T_5c2a4_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_5c2a4_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row6" class="row_heading level0 row6" >in_spotify_playlists</th>
#       <td id="T_5c2a4_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_5c2a4_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row7" class="row_heading level0 row7" >in_spotify_charts</th>
#       <td id="T_5c2a4_row7_col0" class="data row7 col0" >int64</td>
#       <td id="T_5c2a4_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row8" class="row_heading level0 row8" >streams</th>
#       <td id="T_5c2a4_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_5c2a4_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row9" class="row_heading level0 row9" >in_apple_playlists</th>
#       <td id="T_5c2a4_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_5c2a4_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row10" class="row_heading level0 row10" >in_apple_charts</th>
#       <td id="T_5c2a4_row10_col0" class="data row10 col0" >int64</td>
#       <td id="T_5c2a4_row10_col1" class="data row10 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row11" class="row_heading level0 row11" >in_deezer_playlists</th>
#       <td id="T_5c2a4_row11_col0" class="data row11 col0" >object</td>
#       <td id="T_5c2a4_row11_col1" class="data row11 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row12" class="row_heading level0 row12" >in_deezer_charts</th>
#       <td id="T_5c2a4_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_5c2a4_row12_col1" class="data row12 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row13" class="row_heading level0 row13" >in_shazam_charts</th>
#       <td id="T_5c2a4_row13_col0" class="data row13 col0" >object</td>
#       <td id="T_5c2a4_row13_col1" class="data row13 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row14" class="row_heading level0 row14" >bpm</th>
#       <td id="T_5c2a4_row14_col0" class="data row14 col0" >int64</td>
#       <td id="T_5c2a4_row14_col1" class="data row14 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row15" class="row_heading level0 row15" >key</th>
#       <td id="T_5c2a4_row15_col0" class="data row15 col0" >object</td>
#       <td id="T_5c2a4_row15_col1" class="data row15 col1" >95</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row16" class="row_heading level0 row16" >mode</th>
#       <td id="T_5c2a4_row16_col0" class="data row16 col0" >object</td>
#       <td id="T_5c2a4_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row17" class="row_heading level0 row17" >danceability_%</th>
#       <td id="T_5c2a4_row17_col0" class="data row17 col0" >int64</td>
#       <td id="T_5c2a4_row17_col1" class="data row17 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row18" class="row_heading level0 row18" >valence_%</th>
#       <td id="T_5c2a4_row18_col0" class="data row18 col0" >int64</td>
#       <td id="T_5c2a4_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row19" class="row_heading level0 row19" >energy_%</th>
#       <td id="T_5c2a4_row19_col0" class="data row19 col0" >int64</td>
#       <td id="T_5c2a4_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row20" class="row_heading level0 row20" >acousticness_%</th>
#       <td id="T_5c2a4_row20_col0" class="data row20 col0" >int64</td>
#       <td id="T_5c2a4_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row21" class="row_heading level0 row21" >instrumentalness_%</th>
#       <td id="T_5c2a4_row21_col0" class="data row21 col0" >int64</td>
#       <td id="T_5c2a4_row21_col1" class="data row21 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row22" class="row_heading level0 row22" >liveness_%</th>
#       <td id="T_5c2a4_row22_col0" class="data row22 col0" >int64</td>
#       <td id="T_5c2a4_row22_col1" class="data row22 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_5c2a4_level0_row23" class="row_heading level0 row23" >speechiness_%</th>
#       <td id="T_5c2a4_row23_col0" class="data row23 col0" >int64</td>
#       <td id="T_5c2a4_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 2. Basic Descriptive Statistics
# What are the mean, median, and standard deviation of the streams column?

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Convert the 'streams' column to numeric, handling errors
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Calculate the mean, median, and standard deviation of the 'streams' column
streams_stats = df['streams'].agg(['mean', 'median', 'std'])

# Display the results with styling
streams_stats.to_frame().style.set_table_styles([
    {'selector': 'table', 'props': [('border', '1px solid black')]},
    {'selector': 'th', 'props': [('background-color', 'green'), ('color', 'white'), ('border', '1px solid black')]},
    {'selector': 'td', 'props': [('background-color', 'black'), ('color', 'white'), ('border', '1px solid black')]},
])
# Out:
# <style type="text/css">
# #T_89dc4 table {
#   border: 1px solid black;
# }
# #T_89dc4 th {
#   background-color: green;
#   color: white;
#   border: 1px solid black;
# }
# #T_89dc4 td {
#   background-color: black;
#   color: white;
#   border: 1px solid black;
# }
# </style>
# <table id="T_89dc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89dc4_level0_col0" class="col_heading level0 col0" >streams</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89dc4_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_89dc4_row0_col0" class="data row0 col0" >514137424.939076</td>
#     </tr>
#     <tr>
#       <th id="T_89dc4_level0_row1" class="row_heading level0 row1" >median</th>
#       <td id="T_89dc4_row1_col0" class="data row1 col0" >290530915.000000</td>
#     </tr>
#     <tr>
#       <th id="T_89dc4_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_89dc4_row2_col0" class="data row2 col0" >566856949.038883</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Convert the 'streams' column to numeric, handling errors
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Calculate the mean, median, and standard deviation of the 'streams' column
streams_mean = df['streams'].mean()
streams_median = df['streams'].median()
streams_std = df['streams'].std()

# Create a histogram of the 'streams' column
plt.hist(df['streams'], bins=20)
plt.xlabel('Streams')
plt.ylabel('Frequency')
plt.title('Distribution of Streams')

# Add vertical lines for the mean, median, and standard deviation
plt.axvline(streams_mean, color='y', linestyle='--', label=f'Mean: {streams_mean:.2f}')
plt.axvline(streams_median, color='m', linestyle='-', label=f'Median: {streams_median:.2f}')
plt.axvline(streams_mean + streams_std, color='r', linestyle=':', label=f'Std Dev: {streams_std:.2f}')


plt.legend()
plt.show()

# %% [markdown]
# What is the distribution of released_year and artist_count? Are there any noticeable trends or outliers?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# --- Released Year Distribution ---
plt.figure(figsize=(10, 5))
plt.hist(df['released_year'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Released Year')
plt.ylabel('Frequency')
plt.title('Distribution of Released Years')
plt.show()

# --- Artist Count Distribution ---

# Assuming 'artist_count' is a column representing the number of artists per song
# If not, you'll need to create this column first

# Example: If 'artists' column contains a list of artists separated by commas
df['artist_count'] = df['artist(s)_name'].str.split(',').apply(len)

plt.figure(figsize=(10, 5))
plt.hist(df['artist_count'], bins=10, color='coral', edgecolor='black')
plt.xlabel('Number of Artists')
plt.ylabel('Frequency')
plt.title('Distribution of Artist Count')
plt.show()

# --- Trends and Outliers ---
print("Descriptive statistics for Released Year:")
print(df['released_year'].describe())

print("\nDescriptive statistics for Artist Count:")
print(df['artist_count'].describe())

# Outlier detection for released year (using IQR)
Q1 = df['released_year'].quantile(0.25)
Q3 = df['released_year'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['released_year'] < lower_bound) | (df['released_year'] > upper_bound)]

print(f"\nOutliers for released year:")
if not outliers.empty:
  print(outliers[['track_name', 'artist(s)_name', 'released_year']].to_string(index=False))
else:
  print("No outliers found for released year.")

# Outlier detection for artist count (using IQR)
Q1 = df['artist_count'].quantile(0.25)
Q3 = df['artist_count'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['artist_count'] < lower_bound) | (df['artist_count'] > upper_bound)]

print(f"\nOutliers for artist count:")
if not outliers.empty:
  # Use tabulate to make the table neater
  # !pip install tabulate
  from tabulate import tabulate
  print(tabulate(outliers[['track_name', 'artist(s)_name', 'artist_count']], headers='keys', tablefmt='psql'))
else:
  print("No outliers found for artist count.")

# Further analysis and visualization can be done based on these initial findings
# For example, you might want to create scatter plots, box plots, or investigate
# specific years or artist counts in more detail.
# Out:
# Descriptive statistics for Released Year:
# count     953.000000
# mean     2018.238195
# std        11.116218
# min      1930.000000
# 25%      2020.000000
# 50%      2022.000000
# 75%      2022.000000
# max      2023.000000
# Name: released_year, dtype: float64
#
# Descriptive statistics for Artist Count:
# count    953.000000
# mean       1.555089
# std        0.887209
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        8.000000
# Name: artist_count, dtype: float64
#
# Outliers for released year:
#                                                                        track_name                                                          artist(s)_name  released_year
#                                                                  I Wanna Be Yours                                                          Arctic Monkeys           2013
#                                                                       Blank Space                                                            Taylor Swift           2014
#                                                                             Style                                                            Taylor Swift           2014
#                                                                       Die For You                                                              The Weeknd           2016
#                                                                           Starboy                                                   The Weeknd, Daft Punk           2016
#                                                                      Another Love                                                               Tom Odell           2012
#                                                                            Yellow                                                           Chris Molitor           1999
#                                                                   Sweater Weather                                                       The Neighbourhood           2012
#                                                                      Viva La Vida                                                                Coldplay           2008
#                                                                           Riptide                                                               Vance Joy           1975
#                                                                            Makeba                                                                    Jain           2015
#                                                                MONTAGEM - FR PUNK                                                      Ayparia, unxbected           2012
#                                                                Summertime Sadness                                                            Lana Del Rey           2011
#                                                                             Lover                                                            Taylor Swift           2012
#                                                                       Mockingbird                                                                  Eminem           2004
#                                                              Set Fire to the Rain                                                                   Adele           2011
#                                                                       Money Trees                                                Kendrick Lamar, Jay Rock           2012
#                                                 Everybody Wants To Rule The World                                                         Tears For Fears           1985
#                                                                    No Role Modelz                                                                 J. Cole           2014
#                                                  Can't Hold Us (feat. Ray Dalton)                                      Ray Dalton, Ryan Lewis, Macklemore           2011
#                                                                             Radio                                                            Lana Del Rey           2011
#                                                                               505                                                          Arctic Monkeys           2007
#                                                                        Without Me                                                                  Eminem           2002
#                                                                Stargirl Interlude                                                The Weeknd, Lana Del Rey           2016
#                                                            Somewhere Only We Know                                                                   Keane           2004
#                                                                      Danza Kuduro                                                       Don Omar, Lucenzo           2010
#                                                              Locked Out Of Heaven                                                              Bruno Mars           2012
#                                                                    Counting Stars                                                             OneRepublic           2013
#                                                                          Gasolina                                                            Daddy Yankee           2004
#                                                                         One Dance                                                     Drake, WizKid, Kyla           2016
#                                                                         Enchanted                                                            Taylor Swift           2010
#                                                                        Sure Thing                                                                  Miguel           2010
#                                           Every Breath You Take - Remastered 2003                                                              The Police           1983
#                                                                  The Night We Met                                                              Lord Huron           2015
#                                                                     We Found Love                                                  Rihanna, Calvin Harris           2011
#                                                               When I Was Your Man                                                              Bruno Mars           2012
#                                                                  Do I Wanna Know?                                                          Arctic Monkeys           2013
#                                                                            Demons                                                         Imagine Dragons           2012
#                                                                          Reminder                                                              The Weeknd           2016
#                                                                      Shake It Off                                                            Taylor Swift           2014
#                                          Why'd You Only Call Me When You're High?                                                          Arctic Monkeys           2013
#                                                                     Night Changes                                                           One Direction           2014
#                                                                             Creep                                                               Radiohead           1992
#                                                                      Pink + White                                                             Frank Ocean           2016
#                                                              Just The Way You Are                                                              Bruno Mars           2010
#                                                                 Take Me To Church                                                                  Hozier           2013
#                                                      Have You Ever Seen The Rain?                                            Creedence Clearwater Revival           1968
#                                                                     Es un Secreto                                                                  Plan B           2010
#                                                                        Take On Me                                                                    a-ha           1984
#                                                                       Unstoppable                                                                     Sia           2016
#                                                               The Real Slim Shady                                                                  Eminem           2000
#                             Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½ï¿½ Spe                                                            sped up 8282           1997
#                                                                       Lovers Rock                                                                 TV Girl           2014
#                                                Lose Yourself - Soundtrack Version                                                                  Eminem           2002
#                                                                          Superman                                                        Eminem, Dina Rae           2002
#                                                                Gangsta's Paradise                                                            Coolio, L.V.           1995
#                                                                     I Love You So                                                             The Walters           2014
#                                                              Say You Won't Let Go                                                            James Arthur           2016
#                                                                         The Hills                                                              The Weeknd           2015
#                                                                              Numb                                                             Linkin Park           2003
#                                                                       Bloody Mary                                                               Lady Gaga           2011
#                                                                        In The End                                                             Linkin Park           2000
#                                                                  Sex, Drugs, Etc.                                                           Beach Weather           2016
#                                                                      Hey, Mickey!                                                               Baby Tate           2016
#                                                                        Space Song                                                             Beach House           2015
#                                                              I'm Not The Only One                                                               Sam Smith           2014
#                                                                        After Dark                                                                Mr.Kitty           2014
#                                                                          Atlantis                                                                 Seafret           2015
#                                            Running Up That Hill (A Deal With God)                                                               Kate Bush           1985
#                                                                          Dream On                                                               Aerosmith           1973
#                                                                   Agudo Mï¿½ï¿½gi                                                 Styrx, utku INC, Thezth           1930
#                                                                          Payphone                                                   Maroon 5, Wiz Khalifa           2012
#                                                   All I Want for Christmas Is You                                                            Mariah Carey           1994
#                                                                    Last Christmas                                                                   Wham!           1984
#                                                 Rockin' Around The Christmas Tree                                                              Brenda Lee           1958
#                                                                  Jingle Bell Rock                                                             Bobby Helms           1957
#                                       It's Beginning To Look A Lot Like Christmas                                                          Michael Bublï¿           2011
#                                                                     Santa Tell Me                                                           Ariana Grande           2013
#                                          It's the Most Wonderful Time of the Year                                                           Andy Williams           1963
#                                            Let It Snow! Let It Snow! Let It Snow!                                                             Dean Martin           1959
#                                                               Underneath the Tree                                                          Kelly Clarkson           2013
#                                                                     Feliz Navidad                                                         Josï¿½ï¿½ Felic           1970
#                                                             Holly Jolly Christmas                                                          Michael Bublï¿           2011
#                                                                         Mistletoe                                                           Justin Bieber           2011
#                                                                       Sleigh Ride                                                            The Ronettes           1963
#                                                          Happy Xmas (War Is Over) John Lennon, The Harlem Community Choir, The Plastic Ono Band, Yoko Ono           1971
#                                          A Holly Jolly Christmas - Single Version                                                               Burl Ives           1952
#                     The Christmas Song (Merry Christmas To You) - Remastered 1999                                                           Nat King Cole           1946
#                        Wonderful Christmastime - Edited Version / Remastered 2011                                                          Paul McCartney           1979
#                                       Do They Know It's Christmas? - 1984 Version                                                                Band Aid           1984
#                                                          Merry Christmas Everyone                                                         Shakin' Stevens           1984
#                                            Let It Snow! Let It Snow! Let It Snow!                                       Frank Sinatra, B. Swanson Quartet           1950
#                                                                   White Christmas      Bing Crosby, John Scott Trotter & His Orchestra, Ken Darby Singers           1942
#                                        Driving Home for Christmas - 2019 Remaster                                                               Chris Rea           1986
#                                                 Christmas (Baby Please Come Home)                                                            Darlene Love           1963
# It's Beginning to Look a Lot Like Christmas (with Mitchell Ayres & His Orchestra)         Perry Como, The Fontane Sisters, Mitchell Ayres & His Orchestra           1958
#                                                          My Only Wish (This Year)                                                          Britney Spears           2000
#                                                   Deck The Hall - Remastered 1999                                                           Nat King Cole           1959
#                             You Make It Feel Like Christmas (feat. Blake Shelton)                                             Gwen Stefani, Blake Shelton           2005
#                                                  Run Rudolph Run - Single Version                                                             Chuck Berry           1958
#                                                    Jingle Bells - Remastered 1999                                                           Frank Sinatra           1957
#                                               Love Grows (Where My Rosemary Goes)                                                       Edison Lighthouse           1970
#                                                                            Freaks                                                              Surf Curse           2015
#                                                                      Daddy Issues                                                       The Neighbourhood           2015
#                                                               Rolling in the Deep                                                                   Adele           2010
#                                                                            No Lie                                                     Sean Paul, Dua Lipa           2016
#                                                                Pope Is a Rockstar                                                                   SALES           2016
#                                                               Talking To The Moon                                                              Bruno Mars           2010
#                                                                        The Nights                                                                  Avicii           2014
#                                                                         All of Me                                                             John Legend           2013
#                                         Smells Like Teen Spirit - Remastered 2021                                                                 Nirvana           1991
#                                                                    Mr. Brightside                                                             The Killers           2003
#                                                                  'Till I Collapse                                                       Eminem, Nate Dogg           2002
#                                                                      Still D.R.E.                                                     Dr. Dre, Snoop Dogg           1999
#                                                                  The Next Episode                                                     Dr. Dre, Snoop Dogg           1999
#                                                                              Lost                                                             Frank Ocean           2012
#                                                                        In Da Club                                                                 50 Cent           2002
#                                                                Ginseng Strip 2002                                                               Yung Lean           2013
#                                                                            Notion                                                      The Rare Occasions           2016
#                                     California Love - Original Version (Explicit)                                                    Dr. Dre, 2Pac, Roger           1995
#                                                                  Forgot About Dre                                                         Eminem, Dr. Dre           1999
#                                                                              Stan                                                            Eminem, Dido           1999
#                                                                       Alien Blues                                                                Vundabar           2015
#                                                                 Thinking Out Loud                                                              Ed Sheeran           2014
#                                            Something In The Way - Remastered 2021                                                                 Nirvana           1991
#                                                       Yo Voy (feat. Daddy Yankee)                                                           Zion & Lennox           2004
#                                                             Thinking with My Dick                                                    Kevin Gates, Juicy J           2013
#                                               Bohemian Rhapsody - Remastered 2011                                                                   Queen           1975
#                                                           Wake Me Up - Radio Edit                                                                  Avicii           2013
#                                                                            Closer                                                The Chainsmokers, Halsey           2016
#                                                      Somebody That I Used To Know                                                           Gotye, Kimbra           2011
#                                                                    Wait a Minute!                                                                  Willow           2015
#                                                               Cool for the Summer                                                             Demi Lovato           2015
#                                                                             Sigue                                                    Ed Sheeran, J Balvin           1996
#                                                   There's Nothing Holdin' Me Back                                                            Shawn Mendes           2016
#                                                            Get Lucky - Radio Edit                              Pharrell Williams, Nile Rodgers, Daft Punk           2013
#                                                                        Photograph                                                              Ed Sheeran           2014
#                                                                     Love Yourself                                                           Justin Bieber           2015
#                                                                 House Of Memories                                                     Panic! At The Disco           2016
#                                                                              Iris                                                       The Goo Goo Dolls           1998
#                                                                  Pass The Dutchie                                                           Musical Youth           1982
#                                                      Only Love Can Hurt Like This                                                            Paloma Faith           2014
#                                                                  Me and Your Mama                                                        Childish Gambino           2016
#                                                    Master of Puppets (Remastered)                                                               Metallica           1986
#                                                               Sweet Child O' Mine                                                           Guns N' Roses           1987
#                                                                         Heartless                                                              Kanye West           2008
#                                                                           Bound 2                                                              Kanye West           2013
#                                                                     The Scientist                                                                Coldplay           2002
#                                                                            Sparks                                                                Coldplay           2000
#                                                                           Selfish                                                                PnB Rock           2016
#                                                                          Miss You                                                               Southstar           1982
#
# Outliers for artist count:
# Requirement already satisfied: tabulate in c:\users\grace cerad\anaconda3\lib\site-packages (0.9.0)
# +-----+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+----------------+
# |     | track_name                                                                                                                  | artist(s)_name                                                                                                              |   artist_count |
# |-----+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+----------------|
# |  35 | Los del Espacio                                                                                                             | Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk                                                |              8 |
# | 135 | Calling (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, NAV, feat. A Boogie Wit da Hoodie)                  | Swae Lee, A Boogie Wit da Hoodie, Metro Boomin, NAV                                                                         |              4 |
# | 137 | Tere Vaaste (From "Zara Hatke Zara Bachke")                                                                                 | Sachin-Jigar, Shadab Faridi, Altamash Faridi, Amitabh Bhattacharya, Varun Jain                                              |              5 |
# | 141 | Novo Balanï¿½                                                                                                               | Veigh, Bvga Beatz, Supernova Ent, Prod Malax                                                                                |              4 |
# | 197 | POLARIS - Remix                                                                                                             | Feid, Mora, Saiko, Quevedo                                                                                                  |              4 |
# | 200 | Annihilate (Spider-Man: Across the Spider-Verse) (Metro Boomin & Swae Lee, Lil Wayne, Offset)                               | Swae Lee, Lil Wayne, Offset, Metro Boomin                                                                                   |              4 |
# | 201 | Angel Pt 1 (feat. Jimin of BTS, JVKE & Muni Long)                                                                           | Kodak Black, NLE Choppa, Muni Long, JVKE, Jimin                                                                             |              5 |
# | 238 | Link Up (Metro Boomin & Don Toliver, Wizkid feat. BEAM & Toian) - Spider-Verse Remix (Spider-Man: Across the Spider-Verse ) | WizKid, Toian, Metro Boomin, Don Toliver, Beam                                                                              |              5 |
# | 328 | Marisola - Remix                                                                                                            | Duki, NICKI NICOLE, Cris Mj, Standly, Stars Music Chile                                                                     |              5 |
# | 365 | Enemy (with JID) - from the series Arcane League of Legends                                                                 | Imagine Dragons, League of Legends, JID, Arcane                                                                             |              4 |
# | 393 | Jhoome Jo Pathaan                                                                                                           | Arijit Singh, Vishal Dadlani, Sukriti Kakar, Vishal-Shekhar, Shekhar Ravjiani, Kumaar                                       |              6 |
# | 402 | Besharam Rang (From "Pathaan")                                                                                              | Vishal-Shekhar, Shilpa Rao, Caralisa Monteiro, Kumaar, Vishal Dadlani, Shekhar Ravjiani                                     |              6 |
# | 457 | Happy Xmas (War Is Over)                                                                                                    | John Lennon, The Harlem Community Choir, The Plastic Ono Band, Yoko Ono                                                     |              4 |
# | 488 | Tubarï¿½ï¿½o Te                                                                                                             | Dj LK da Escï¿½ï¿½cia, Tchakabum, mc jhenny, M                                                                              |              4 |
# | 506 | We Don't Talk About Bruno                                                                                                   | Adassa, Mauro Castillo, Stephanie Beatriz, Encanto - Cast, Rhenzy Feliz, Diane Guerrero, Carolina Gaitan                    |              7 |
# | 540 | Entre Nosotros (Remix) [con Nicki Nicole]                                                                                   | Lit Killah, Maria Becerra, Tiago pzk, NICKI NICOLE                                                                          |              4 |
# | 605 | OUT OUT (feat. Charli XCX & Saweetie)                                                                                       | Charli XCX, Jax Jones, Joel Corry, Saweetie                                                                                 |              4 |
# | 638 | Friday (feat. Mufasa & Hypeman) - Dopamine Re-Edit                                                                          | Riton, Nightcrawlers, Mufasa & Hypeman, Dopamine                                                                            |              4 |
# | 642 | Se Le Ve                                                                                                                    | Arcangel, De La Ghetto, Justin Quiles, Lenny Tavï¿½ï¿½rez, Sech, Dalex, Dimelo Flow, Rich Music                             |              8 |
# | 667 | Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Abhir Hathi, Bejo, EL IMA)                                                      | Quevedo, La Pantera, Juseph, Cruz Cafunï¿½ï¿½, Bï¿½ï¿½jo, Abhir Hathi                                                       |              6 |
# | 749 | sentaDONA (Remix) s2                                                                                                        | Luï¿½ï¿½sa Sonza, MC Frog, Dj Gabriel do Borel, Davi K                                                                      |              4 |
# | 759 | Nobody Like U - From "Turning Red"                                                                                          | Jordan Fisher, Josh Levi, Finneas O'Connell, 4*TOWN (From Disney and Pixarï¿½ï¿½ï¿½s Turning Red), Topher Ngo, Grayson Vill |              6 |
# | 833 | Cash In Cash Out                                                                                                            | Pharrell Williams, Tyler, The Creator, 21 Savage                                                                            |              4 |
# | 837 | La Llevo Al Cielo (Ft. ï¿½ï¿½engo F                                                                                         | Nengo Flow, Anuel Aa, Chris Jedi, Chencho Corleone                                                                          |              4 |
# | 864 | ULTRA SOLO REMIX                                                                                                            | De La Ghetto, Feid, Polima WestCoast, Paloma Mami, Pailita                                                                  |              5 |
# | 894 | Stay With Me (with Justin Timberlake, Halsey, & Pharrell)                                                                   | Calvin Harris, Halsey, Pharrell Williams, Justin Timberlake                                                                 |              4 |
# | 920 | BABY OTAKU                                                                                                                  | Fran C, Polima WestCoast, Nickoog Clk, Pablito Pesadilla                                                                    |              4 |
# +-----+-----------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------+----------------+

# %% [markdown]
# 3. Top Perfomers
# Which track has the highest number of streams? Display the top 5 most streamed tracks.

# %%
import pandas as pd
# !pip install prettytable
from prettytable import PrettyTable

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Convert the 'streams' column to numeric, handling errors
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Function to format stream count
def format_streams(streams):
  if streams >= 1e9:
    return f"{streams/1e9:.1f}B"
  elif streams >= 1e6:
    return f"{streams/1e6:.1f}M"
  else:
    return f"{streams:,.0f}"

# Apply the formatting to the streams column
df['formatted_streams'] = df['streams'].apply(format_streams)

# Sort the DataFrame by streams in descending order
df_sorted = df.sort_values(by='streams', ascending=False)

# Display the top 5 most streamed tracks with formatted streams
top_5_tracks = df_sorted[['track_name', 'artist(s)_name', 'formatted_streams']].head(5)

# Use prettytable to display the results in a formatted table
table = PrettyTable()
table.field_names = ["Track Name", "artist(s)_name", "Streams"]
for index, row in top_5_tracks.iterrows():
    table.add_row([row['track_name'], row['artist(s)_name'], row['formatted_streams']])

# Add some styling
table.align = "l"  # Left align text
table.hrules = 1  # Add horizontal lines between rows

print(table)
# Out:
# Collecting prettytable
#   Downloading prettytable-3.11.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: wcwidth in c:\users\grace cerad\anaconda3\lib\site-packages (from prettytable) (0.2.5)
# Downloading prettytable-3.11.0-py3-none-any.whl (28 kB)
# Installing collected packages: prettytable
# Successfully installed prettytable-3.11.0
# +-----------------------------------------------+-----------------------+---------+
# | Track Name                                    | artist(s)_name        | Streams |
# +-----------------------------------------------+-----------------------+---------+
# | Blinding Lights                               | The Weeknd            | 3.7B    |
# +-----------------------------------------------+-----------------------+---------+
# | Shape of You                                  | Ed Sheeran            | 3.6B    |
# +-----------------------------------------------+-----------------------+---------+
# | Someone You Loved                             | Lewis Capaldi         | 2.9B    |
# +-----------------------------------------------+-----------------------+---------+
# | Dance Monkey                                  | Tones and I           | 2.9B    |
# +-----------------------------------------------+-----------------------+---------+
# | Sunflower - Spider-Man: Into the Spider-Verse | Post Malone, Swae Lee | 2.8B    |
# +-----------------------------------------------+-----------------------+---------+

# %% [markdown]
# Who are the top 5 most frequent artists based on the number of tracks in the dataset?

# %%
# prompt: create a program that states the 5 most frequent artists based on the number of tracks in the dataset, make the data in table form with styling

import pandas as pd
# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Group by artist and count the number of tracks
artist_track_counts = df.groupby('artist(s)_name')['track_name'].count().sort_values(ascending=False)

# Get the top 5 most frequent artists
top_5_artists = artist_track_counts.head(5)

# Create a PrettyTable for the results
table = PrettyTable()
table.field_names = ["Artist", "Number of Tracks"]

for artist, count in top_5_artists.items():
  table.add_row([artist, count])

# Add some styling
table.align = "l"  # Left align text
table.hrules = 1  # Add horizontal lines between rows

# Display the table
print(table)
# Out:
# +--------------+------------------+
# | Artist       | Number of Tracks |
# +--------------+------------------+
# | Taylor Swift | 34               |
# +--------------+------------------+
# | The Weeknd   | 22               |
# +--------------+------------------+
# | SZA          | 19               |
# +--------------+------------------+
# | Bad Bunny    | 19               |
# +--------------+------------------+
# | Harry Styles | 17               |
# +--------------+------------------+

# %% [markdown]
# 4. Temporal Trends
#
# Analyze the trends in the number of tracks released over time. Plot the number of tracks released per year.

# %%
# prompt: Create a program that Analyze the trends in the number of tracks released over time. Plot the number of tracks
# released per year, make it in a stylized graph add a grid line

import pandas as pd
import matplotlib.pyplot as plt
# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Group by released year and count the number of tracks
tracks_per_year = df.groupby('released_year')['track_name'].count()

# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(tracks_per_year.index, tracks_per_year.values, marker='o', linestyle='-', color='green')

# Add title and labels
plt.title('Number of Tracks Released Per Year', fontsize=20)
plt.xlabel('Released Year', fontsize=14)
plt.ylabel('Number of Tracks', fontsize=14)

# Customize the grid
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines

# Add styling
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout for better spacing


# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Count occurrences of each month value in 'released_month'
month_counts = df['released_month'].value_counts().sort_index()

# Ensure all months from 1 to 12 are included
month_counts = month_counts.reindex(range(1, 13), fill_value=0)

# Create a bar graph with value labels
plt.figure(figsize=(10, 5))
bars = plt.bar(month_counts.index, month_counts.values, color='green')

# Set x-axis labels to month names
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(range(1, 13), month_names)

# Add labels and title
plt.xlabel("Month")
plt.ylabel("Number of Occurrences")
plt.title("Occurrences of Months in 'released_month'")

# Add gridlines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Remove top and right spines
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Add value labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height,
             str(int(height)), ha='center', va='bottom')

# Show the plot
plt.show()

# %% [markdown]
# 5. Genre and Music Characteristics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Convert 'streams' column to numeric
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Select relevant columns for correlation analysis
attributes = ['bpm', 'danceability_%', 'energy_%']
df_corr = df[['streams'] + attributes].dropna()

# Calculate correlation matrix
corr_matrix = df_corr.corr()

# Create a heatmap 
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='Greens', fmt=".2f", linewidths=.5, annot_kws={"size": 14})
plt.title('Correlation Matrix of Streams and Musical Attributes', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# Identify attributes with highest correlation to streams
corr_with_streams = corr_matrix['streams'].drop('streams')
most_influential = corr_with_streams[abs(corr_with_streams) == abs(corr_with_streams).max()]

print("\nAttribute(s) with the strongest influence on streams:")
print(most_influential)
# Out:
# Attribute(s) with the strongest influence on streams:
# danceability_%   -0.105457
# Name: streams, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Select relevant columns for correlation analysis
attributes1 = ['danceability_%', 'energy_%']
attributes2 = ['valence_%', 'acousticness_%']

# Calculate correlation matrices
corr_matrix1 = df[attributes1].corr()
corr_matrix2 = df[attributes2].corr()

# Create heatmaps 
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.heatmap(corr_matrix1, annot=True, cmap='Greens', fmt=".2f", linewidths=.5, annot_kws={"size": 14}, ax=axes[0])
axes[0].set_title('Correlation between Danceability and Energy', fontsize=16)
axes[0].tick_params(labelsize=12)

sns.heatmap(corr_matrix2, annot=True, cmap='Greens', fmt=".2f", linewidths=.5, annot_kws={"size": 14}, ax=axes[1]) 
axes[1].set_title('Correlation between Valence and Acousticness', fontsize=16)
axes[1].tick_params(labelsize=12)

plt.tight_layout()
plt.show()

# Print correlation values
print(f"\nCorrelation between danceability_% and energy_%: {corr_matrix1.iloc[0, 1]:.2f}")
print(f"Correlation between valence_% and acousticness_%: {corr_matrix2.iloc[0, 1]:.2f}")
# Out:
# Correlation between danceability_% and energy_%: 0.20
# Correlation between valence_% and acousticness_%: -0.08

# %% [markdown]
# 6. Platform Popularity

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Count tracks in each platform's playlists
platform_counts = df[['in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists','in_apple_charts']].sum()

# Create a bar graph
plt.figure(figsize=(8, 6))
plt.bar(platform_counts.index, platform_counts.values, color=['green', 'blue', 'red'])
plt.xlabel("Platform")
plt.ylabel("Number of Tracks")
plt.title("Number of Tracks in Playlists on Different Platforms")

# Add value labels above each bar
for i, v in enumerate(platform_counts.values):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# Identify the platform with the most popular tracks
most_popular_platform = platform_counts.idxmax()
print(f"\n{most_popular_platform} seems to favor the most popular tracks.")
# Out:
# in_spotify_playlists seems to favor the most popular tracks.

# %% [markdown]
# 7. Musical Notes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Convert 'streams' column to numeric
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Group data by key and mode and calculate average streams
key_mode_streams = df.groupby(['key', 'mode'])['streams'].mean().reset_index()

# Create a box plot for streams by key
plt.figure(figsize=(12, 6))
sns.boxplot(x='key', y='streams', data=df, hue='mode', palette={'Major': 'red', 'Minor': 'green'})
plt.title('Distribution of Streams by Key and Mode')
plt.xlabel('Key')
plt.ylabel('Streams')
plt.show()

# Calculate average streams for major and minor keys
major_streams = df[df['mode'] == 'Major']['streams'].mean()
minor_streams = df[df['mode'] == 'Minor']['streams'].mean()

print(f"\nAverage streams for tracks in Major key: {major_streams:.2f}")
print(f"Average streams for tracks in Minor key: {minor_streams:.2f}")

# Further analysis could involve:
# - Comparing streams across different keys within major or minor modes
# - Investigating the relationship between key, mode, and other attributes like danceability or energy
# - Analyzing trends over time for different keys and modes
# Out:
# Average streams for tracks in Major key: 534832793.34
# Average streams for tracks in Minor key: 485944478.91

# %%
import pandas as pd
from collections import Counter

# Load the dataset
df = pd.read_csv(r'C:\Users\grace cerad\spotify-2023.csv', encoding='latin-1')

# Combine playlist and chart columns for overall presence
df['all_playlists'] = df['in_spotify_playlists'] + df['in_spotify_charts'] + df['in_apple_playlists'] + df['in_apple_charts']

# Get top 10 artists overall
top_10_artists = df['artist(s)_name'].value_counts().head(10).index

# Filter dataframe for top 10 artists
df_top_artists = df[df['artist(s)_name'].isin(top_10_artists)]

# Count playlist occurrences for each artist
playlist_counts = df_top_artists.groupby('artist(s)_name')['all_playlists'].sum().sort_values(ascending=False)

# Print the results
print("Most frequently appearing artists in playlists and charts:\n")
for artist, count in playlist_counts.items():
    print(f"{artist}: {count}")

# Create a bar chart with enhanced design
plt.figure(figsize=(12, 6))
bars = plt.bar(playlist_counts.index, playlist_counts.values, color='lightgreen', edgecolor='black', linewidth=1.5)
plt.xlabel("Artist", fontsize=12)
plt.ylabel("Number of Playlists/Charts", fontsize=12)
plt.title("Top 10 Artists in Playlists and Charts", fontsize=14)
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, str(int(height)),
             ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# Most frequently appearing artists in playlists and charts:
#
# The Weeknd: 147258
# Taylor Swift: 137178
# Ed Sheeran: 130788
# Harry Styles: 112497
# Kendrick Lamar: 59772
# Bad Bunny: 53026
# SZA: 46399
# BTS: 19409
# Feid: 14956
# Morgan Wallen: 9706

# %% [markdown]
# Summary
# 1. Overview of Datasheet
# -
#
# The dataset has 953 rows and 24 column- s.
# The missing values are: in_shazam_charts - 50 and key
# - 95
# 2. Basic Descriptive Statist- ics
#
# The Stream column has the following statistics; Mean - 514,137,424, Median - 290,530,915, Standard Deviation - 566,8- 56,949
# The most played tracks are from 2020s, notably the highest played tracks are consist of one artist. Followed by two artirst an
# d so on.
# 3. Top Per- formers
#
# The Top 5 Top Performing Tracks include; Blinding Lights by The Weeknd, Shape of You by Ed Sheeran, Someone You Loved by Lewis Capaldi, Dance Monkey by Tones and I and Sunflower - Spider-Man: Into the Spider-Verse by * Post Malone,-  Swae Lee*
# The Top 5 Most Frequent Artist were Taylor Swift, The Weeknd, Bad Bunny, SZA, and H
#
# 4. Temporal Trends
# -
# Notably the songs released each year from 1930 up until the early 2000s are stable, while in the 2010 to 2020 the number increased significantly- .
# The number of streams per month are highest during January and May, which is induced by seasonal festivities (January) where most people are on vacation and Music Festivals (Ma
# y).
# 5. Genre and Music Characteristi- cs
#
# The number of tracks released increased significantly after the 2010 and 2020 having the highest nu- mber.
# The correlation between danceability_% and energy_% is 0.20, and the correlation between valence_% and acousticness
# _%: -0.
# 6. Platform Popu- larity
#
# The platform with highes of most played tracks belongs to Spotify playlist, followed by Apple playlist and App
# le charts.
# 7. Advance-  Analysis
#
# Most of the top performing songs are in-  the C# key.
# The artists the lead the music charts are The Weeknd, Taylor Swift, Ed Sheeran, Harry Styles, Kendrick Lamar, Bad Bunny, SZA, BTS, Feid, and Morgan Wallen.arry Styles.

# %% [markdown]
# Analysis of Spotify's 2023 Top Tracks Using Python
#
# Ouassignmentdy utilized Python to analyze Spotify's most popular songs from 2023. We examined various factors including artist information, song attributes such as danceability, and peak popularity dates. Using Python's data visualization libraries, we created informative graphs like bar charts and line graphs to represent our findings. This process allowed us to gain insights into music trends and preferences throughout 2023. The project demonstrated the practical application of Python in processing large datasets and generating visual representations of music popularity trends.
